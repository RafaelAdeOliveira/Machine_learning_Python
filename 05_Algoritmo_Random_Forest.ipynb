# %% [markdown]
# ## Formação Cientista de Dados
# ### Algoritmo Random Forest

# %%
# Importação das bibliotecas
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import confusion_matrix, accuracy_score
from sklearn.ensemble import RandomForestClassifier

# %%
# Carregar base de dados e definicção dos previsores (variáveis independentes - X) e a classe (variável dependente - Y)
credito = pd.read_csv('Credit.csv')
credito
# Out:
#     checking_status  duration                    credit_history  \
# 0                <0         6  'critical/other existing credit'
# 1          0<=X<200        48                   'existing paid'
# 2     'no checking'        12  'critical/other existing credit'
# 3                <0        42                   'existing paid'
# 4                <0        24              'delayed previously'
# ..              ...       ...                               ...
# 995   'no checking'        12                   'existing paid'
# 996              <0        30                   'existing paid'
# 997   'no checking'        12                   'existing paid'
# 998              <0        45                   'existing paid'
# 999        0<=X<200        45  'critical/other existing credit'
#
#                  purpose  credit_amount      savings_status  employment  \
# 0               radio/tv           1169  'no known savings'         >=7
# 1               radio/tv           5951                <100      1<=X<4
# 2              education           2096                <100      4<=X<7
# 3    furniture/equipment           7882                <100      4<=X<7
# 4              'new car'           4870                <100      1<=X<4
# ..                   ...            ...                 ...         ...
# 995  furniture/equipment           1736                <100      4<=X<7
# 996           'used car'           3857                <100      1<=X<4
# 997             radio/tv            804                <100         >=7
# 998             radio/tv           1845                <100      1<=X<4
# 999           'used car'           4576          100<=X<500  unemployed
#
#      installment_commitment       personal_status other_parties  ...  \
# 0                         4         'male single'          none  ...
# 1                         2  'female div/dep/mar'          none  ...
# 2                         2         'male single'          none  ...
# 3                         2         'male single'     guarantor  ...
# 4                         3         'male single'          none  ...
# ..                      ...                   ...           ...  ...
# 995                       3  'female div/dep/mar'          none  ...
# 996                       4        'male div/sep'          none  ...
# 997                       4         'male single'          none  ...
# 998                       4         'male single'          none  ...
# 999                       3         'male single'          none  ...
#
#       property_magnitude age  other_payment_plans     housing  \
# 0          'real estate'  67                 none         own
# 1          'real estate'  22                 none         own
# 2          'real estate'  49                 none         own
# 3       'life insurance'  45                 none  'for free'
# 4    'no known property'  53                 none  'for free'
# ..                   ...  ..                  ...         ...
# 995        'real estate'  31                 none         own
# 996     'life insurance'  40                 none         own
# 997                  car  38                 none         own
# 998  'no known property'  23                 none  'for free'
# 999                  car  27                 none         own
#
#     existing_credits                          job num_dependents  \
# 0                  2                      skilled              1
# 1                  1                      skilled              1
# 2                  1         'unskilled resident'              2
# 3                  1                      skilled              2
# 4                  2                      skilled              2
# ..               ...                          ...            ...
# 995                1         'unskilled resident'              1
# 996                1  'high qualif/self emp/mgmt'              1
# 997                1                      skilled              1
# 998                1                      skilled              1
# 999                1                      skilled              1
#
#      own_telephone foreign_worker class
# 0              yes            yes  good
# 1             none            yes   bad
# 2             none            yes  good
# 3             none            yes  good
# 4             none            yes   bad
# ..             ...            ...   ...
# 995           none            yes  good
# 996            yes            yes  good
# 997           none            yes  good
# 998            yes            yes   bad
# 999           none            yes  good
#
# [1000 rows x 21 columns]

# %%
# Formato de matriz
previsores = credito.iloc[:,0:20].values
classe = credito.iloc[:,20].values

# %%
# Conversão dos atributos categóricos para atributos númericos, passando o índice de cada atributo categórico
labelencoder = LabelEncoder()
previsores[:,0] = labelencoder.fit_transform(previsores[:,0])
previsores[:,2] = labelencoder.fit_transform(previsores[:,2])
previsores[:, 3] = labelencoder.fit_transform(previsores[:, 3])
previsores[:, 5] = labelencoder.fit_transform(previsores[:, 5])
previsores[:, 6] = labelencoder.fit_transform(previsores[:, 6])
previsores[:, 8] = labelencoder.fit_transform(previsores[:, 8])
previsores[:, 9] = labelencoder.fit_transform(previsores[:, 9])
previsores[:, 11] = labelencoder.fit_transform(previsores[:, 11])
previsores[:, 13] = labelencoder.fit_transform(previsores[:, 13])
previsores[:, 14] = labelencoder.fit_transform(previsores[:, 14])
previsores[:, 16] = labelencoder.fit_transform(previsores[:, 16])
previsores[:, 18] = labelencoder.fit_transform(previsores[:, 18])
previsores[:, 19] = labelencoder.fit_transform(previsores[:, 19])

# %%
# Divisão da base de dados entre treinamento e teste (30% para testar e 70% para treinar)
X_treinamento, X_teste, y_treinamento, y_teste = train_test_split(previsores,
                                                                 classe,
                                                                 test_size = 0.3,
                                                                 random_state = 0)
X_teste
# Out:
# array([[2, 36, 3, ..., 1, 1, 1],
#        [0, 9, 3, ..., 2, 0, 0],
#        [0, 18, 3, ..., 1, 1, 1],
#        ...,
#        [0, 24, 1, ..., 1, 0, 1],
#        [1, 27, 4, ..., 1, 1, 1],
#        [1, 12, 3, ..., 1, 0, 1]], dtype=object)

# %%
# Criação do modelo, treinamento, obtenção das previsões e da taxa de acerto
floresta = RandomForestClassifier(n_estimators = 100)
floresta.fit(X_treinamento, y_treinamento)
# Out:
# RandomForestClassifier()

# %%
# Visualização dos atributos principais
floresta.estimators_
#floresta.estimators_[1]
# Out:
# [DecisionTreeClassifier(max_features='auto', random_state=896110383),
#  DecisionTreeClassifier(max_features='auto', random_state=622198939),
#  DecisionTreeClassifier(max_features='auto', random_state=523149460),
#  DecisionTreeClassifier(max_features='auto', random_state=918334495),
#  DecisionTreeClassifier(max_features='auto', random_state=1119023827),
#  DecisionTreeClassifier(max_features='auto', random_state=2077701469),
#  DecisionTreeClassifier(max_features='auto', random_state=684015319),
#  DecisionTreeClassifier(max_features='auto', random_state=870297190),
#  DecisionTreeClassifier(max_features='auto', random_state=507700417),
#  DecisionTreeClassifier(max_features='auto', random_state=1311605788),
#  DecisionTreeClassifier(max_features='auto', random_state=585245765),
#  DecisionTreeClassifier(max_features='auto', random_state=1321276131),
#  DecisionTreeClassifier(max_features='auto', random_state=536760732),
#  DecisionTreeClassifier(max_features='auto', random_state=827924959),
#  DecisionTreeClassifier(max_features='auto', random_state=1187866380),
#  DecisionTreeClassifier(max_features='auto', random_state=394605197),
#  DecisionTreeClassifier(max_features='auto', random_state=208443129),
#  DecisionTreeClassifier(max_features='auto', random_state=1099261027),
#  DecisionTreeClassifier(max_features='auto', random_state=1714465001),
#  DecisionTreeClassifier(max_features='auto', random_state=82596103),
#  DecisionTreeClassifier(max_features='auto', random_state=1345421220),
#  DecisionTreeClassifier(max_features='auto', random_state=2062303763),
#  DecisionTreeClassifier(max_features='auto', random_state=1169383321),
#  DecisionTreeClassifier(max_features='auto', random_state=40483338),
#  DecisionTreeClassifier(max_features='auto', random_state=43503080),
#  DecisionTreeClassifier(max_features='auto', random_state=673424622),
#  DecisionTreeClassifier(max_features='auto', random_state=1741241867),
#  DecisionTreeClassifier(max_features='auto', random_state=1822249932),
#  DecisionTreeClassifier(max_features='auto', random_state=286942147),
#  DecisionTreeClassifier(max_features='auto', random_state=1120860661),
#  DecisionTreeClassifier(max_features='auto', random_state=1496475780),
#  DecisionTreeClassifier(max_features='auto', random_state=915238919),
#  DecisionTreeClassifier(max_features='auto', random_state=1247092549),
#  DecisionTreeClassifier(max_features='auto', random_state=474118629),
#  DecisionTreeClassifier(max_features='auto', random_state=1022083127),
#  DecisionTreeClassifier(max_features='auto', random_state=1817993886),
#  DecisionTreeClassifier(max_features='auto', random_state=1057763813),
#  DecisionTreeClassifier(max_features='auto', random_state=276637513),
#  DecisionTreeClassifier(max_features='auto', random_state=842458850),
#  DecisionTreeClassifier(max_features='auto', random_state=1960601232),
#  DecisionTreeClassifier(max_features='auto', random_state=1993133594),
#  DecisionTreeClassifier(max_features='auto', random_state=1960130398),
#  DecisionTreeClassifier(max_features='auto', random_state=154218602),
#  DecisionTreeClassifier(max_features='auto', random_state=830693211),
#  DecisionTreeClassifier(max_features='auto', random_state=380525182),
#  DecisionTreeClassifier(max_features='auto', random_state=1600440544),
#  DecisionTreeClassifier(max_features='auto', random_state=816218547),
#  DecisionTreeClassifier(max_features='auto', random_state=842533812),
#  DecisionTreeClassifier(max_features='auto', random_state=1422494688),
#  DecisionTreeClassifier(max_features='auto', random_state=672969401),
#  DecisionTreeClassifier(max_features='auto', random_state=631173409),
#  DecisionTreeClassifier(max_features='auto', random_state=1779798027),
#  DecisionTreeClassifier(max_features='auto', random_state=326647075),
#  DecisionTreeClassifier(max_features='auto', random_state=1499134504),
#  DecisionTreeClassifier(max_features='auto', random_state=963308820),
#  DecisionTreeClassifier(max_features='auto', random_state=11782163),
#  DecisionTreeClassifier(max_features='auto', random_state=1520607169),
#  DecisionTreeClassifier(max_features='auto', random_state=2054224362),
#  DecisionTreeClassifier(max_features='auto', random_state=2125091609),
#  DecisionTreeClassifier(max_features='auto', random_state=220853625),
#  DecisionTreeClassifier(max_features='auto', random_state=1473185037),
#  DecisionTreeClassifier(max_features='auto', random_state=188796578),
#  DecisionTreeClassifier(max_features='auto', random_state=285286011),
#  DecisionTreeClassifier(max_features='auto', random_state=77723904),
#  DecisionTreeClassifier(max_features='auto', random_state=1422389023),
#  DecisionTreeClassifier(max_features='auto', random_state=1830775562),
#  DecisionTreeClassifier(max_features='auto', random_state=1284484971),
#  DecisionTreeClassifier(max_features='auto', random_state=1741251546),
#  DecisionTreeClassifier(max_features='auto', random_state=1237343291),
#  DecisionTreeClassifier(max_features='auto', random_state=380465621),
#  DecisionTreeClassifier(max_features='auto', random_state=1836554533),
#  DecisionTreeClassifier(max_features='auto', random_state=408296458),
#  DecisionTreeClassifier(max_features='auto', random_state=39048434),
#  DecisionTreeClassifier(max_features='auto', random_state=334136861),
#  DecisionTreeClassifier(max_features='auto', random_state=219236131),
#  DecisionTreeClassifier(max_features='auto', random_state=1527949208),
#  DecisionTreeClassifier(max_features='auto', random_state=1421350767),
#  DecisionTreeClassifier(max_features='auto', random_state=186058812),
#  DecisionTreeClassifier(max_features='auto', random_state=975511680),
#  DecisionTreeClassifier(max_features='auto', random_state=1150536241),
#  DecisionTreeClassifier(max_features='auto', random_state=777706605),
#  DecisionTreeClassifier(max_features='auto', random_state=697652664),
#  DecisionTreeClassifier(max_features='auto', random_state=733457251),
#  DecisionTreeClassifier(max_features='auto', random_state=335130050),
#  DecisionTreeClassifier(max_features='auto', random_state=222121431),
#  DecisionTreeClassifier(max_features='auto', random_state=395622856),
#  DecisionTreeClassifier(max_features='auto', random_state=2015938268),
#  DecisionTreeClassifier(max_features='auto', random_state=877358559),
#  DecisionTreeClassifier(max_features='auto', random_state=1944508200),
#  DecisionTreeClassifier(max_features='auto', random_state=1751263220),
#  DecisionTreeClassifier(max_features='auto', random_state=1636645838),
#  DecisionTreeClassifier(max_features='auto', random_state=1599642804),
#  DecisionTreeClassifier(max_features='auto', random_state=1453376851),
#  DecisionTreeClassifier(max_features='auto', random_state=1820194520),
#  DecisionTreeClassifier(max_features='auto', random_state=878402921),
#  DecisionTreeClassifier(max_features='auto', random_state=1786295015),
#  DecisionTreeClassifier(max_features='auto', random_state=1903715090),
#  DecisionTreeClassifier(max_features='auto', random_state=218257562),
#  DecisionTreeClassifier(max_features='auto', random_state=845170968),
#  DecisionTreeClassifier(max_features='auto', random_state=905576785)]

# %%
previsoes = floresta.predict(X_teste)
confusao = confusion_matrix(y_teste, previsoes)
taxa_acerto = accuracy_score(y_teste, previsoes)
taxa_acerto
# Out:
# 0.77
